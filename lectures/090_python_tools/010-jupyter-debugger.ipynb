# %% [markdown]
# # A good developer must be a good detective

# %% [markdown]
# There is a bug in this program, how can we find it?

# %%
def maximum(numbers):
    #pass # pass means "do nothing", add your code here
    max_value = 0
    for num in numbers:
        if num > max_value:
            max_value = num
    return max_value

def main():
    print("Let us find the maximum value from the following list:")
    list_of_nums = [1,2,3]
    max_value = maximum(list_of_nums)
    print(max_value)

    print("Let us find the maximum value from another list:")
    list_of_nums = [-1, -2, -3]
    max_value = maximum(list_of_nums)
    print(max_value)
    
main()

# %% [markdown]
# ### Just look through the code, line by line and execute it in your head
# Does the output in your head match the output on screen? If not, where do the two deviate? That is where the error is.

# %% [markdown]
# ### Print internal values, as you execute the program

# %%
def maximum(numbers):
    #pass # pass means "do nothing", add your code here
    max_value = 0
    for num in numbers:
        # print(num) # <= Don't just print the number, add some context around it
        print(f"Current max_value {max_value}")
        print(f"Current number {num}")
        if num > max_value:
            max_value = num
    return max_value

def main():
    print("Let us find the maximum value from the following list:")
    list_of_nums = [1,2,3]
    max_value = maximum(list_of_nums)
    print(max_value)

    print("Let us find the maximum value from another list:")
    list_of_nums = [-1, -2, -3]
    max_value = maximum(list_of_nums)
    print(max_value)
    
main()

# %% [markdown]
# # Jupyter has recently added a debugger!
# For certain versions of conda, you may have to create a new environment, create a Jupyter kernel for it and use that to activate the debugger.

# %% [markdown]
# Use your mouse to add a 'breakpoint' (red dot) in the left hand side lane which contains line numbers:
#
# ![image.png](attachment:43c95d12-9ccb-43fa-8d09-4e3ee23e2beb.png)
#
# This will allow you to _pause_ the program.
#
# Once paused, you can inspect all variables at that time:
#
# ![image.png](attachment:b7fc3c39-710e-4422-b028-a0baabe35023.png)
#
# You can then chose to continue running your program:
#
# ![image.png](attachment:3c4f9248-38ff-4f23-8bfa-c77d3c05c93b.png)
#
# More interestingly, you can execute a single line, then pause again:
#
# ![image.png](attachment:dbf20f0b-a013-4572-9973-4b43966ee6fb.png)
#
# Even more interestingly, if the current line calls a function, you can _go inside_ the function:
#
# ![image.png](attachment:349be829-cb02-4976-b292-21c30e93ceae.png)

# %%
def maximum(numbers):
    #pass # pass means "do nothing", add your code here
    max_value = 0
    for num in numbers:
        if num > max_value:
            max_value = num
    return max_value

def main():
    print("Let us find the maximum value from the following list:")
    list_of_nums = [1,2,3]
    max_value = maximum(list_of_nums)
    print(max_value)

    print("Let us find the maximum value from another list:")
    list_of_nums = [-1, -2, -3]
    max_value = maximum(list_of_nums)
    print(max_value)
    
main()

# %% [markdown]
# **Exercise** Try this in VS Code
#
# Visual code and other editors do an ever better job of integrating the debugger with the user interface. You can generally hover over the variable to view the value.

# %% [markdown]
# ### VS Code even lets you debug a remote (ssh) session!

# %% [markdown]
# Install VS Code's "Remote Development" plugin by Microsoft:
#
# ![image.png](attachment:6d4d4a47-6fc0-44a2-b998-17ed3717ed37.png)
#
# This plugin will let you edit files in remote ssh locations, docker images and WSL enviornments(Windows Linux subsystem):
#
# ![image.png](attachment:dcfae414-d518-4527-9e1c-e8bcd0578b2b.png)

# %% [markdown]
# Create a new ssh session:
#
# ![image.png](attachment:891eed65-d6bf-4651-b3e2-43c409049ff5.png)
#
# Enter yourname@yourhost and follow other prompts (for your passwod, ssh confirmation, remote operating system, etc):
#
# ![image.png](attachment:0701eaa5-bf17-42f4-b5b6-68be4e78536d.png)

# %% [markdown]
# This will open up a new window, dedicated to your remote session:
#
# ![image.png](attachment:239282bb-5c3c-4405-a1f6-3057c783a76f.png)
#
# Perhaps you want to change its color to differentiate it from your local editor?

# %% [markdown]
# One you open a python file on the remote machine, you will be asked to install server side extensions:
#
# ![image.png](attachment:3a9ea76e-8b9a-43f4-bd04-b3f720f7b388.png)
