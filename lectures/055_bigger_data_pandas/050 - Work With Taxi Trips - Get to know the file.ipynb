# %%
import pandas as pd

# %%
data_df = pd.read_feather("../../datasets/taxi-trips/taxi_trips_small.feather")

# %%
data_df.head(3).T
# Out:
#                                                                             0  \
# Trip ID                              2847377eac0bee949bfa1ca27913ed0d3a1f1b81
# Taxi ID                     afe9520e229118e6dbb1fa164a31175e2b95a5f1e968d1...
# Trip Start Timestamp                                   05/18/2019 03:45:00 PM
# Trip End Timestamp                                     05/18/2019 04:00:00 PM
# Trip Seconds                                                              540
# Trip Miles                                                                  0
# Pickup Census Tract                                               1.70313e+10
# Dropoff Census Tract                                              1.70311e+10
# Pickup Community Area                                                      32
# Dropoff Community Area                                                      8
# Fare                                                                        8
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11311524 entries, 0 to 11311523
# Data columns (total 24 columns):
# Trip ID                       object
# Taxi ID                       object
# Trip Start Timestamp          object
# Trip End Timestamp            object
# Trip Seconds                  float64
# Trip Miles                    float64
# Pickup Census Tract           float64
# Dropoff Census Tract          float64
# Pickup Community Area         float64
# Dropoff Community Area        float64
# Fare                          float64
# Tips                          float64
# Tolls                         float64
# Extras                        float64
# Trip Total                    float64
# Payment Type                  object
# Company                       object
# Pickup Centroid Latitude      float64
# Pickup Centroid Longitude     float64
# Pickup Centroid Location      object
# Dropoff Centroid Latitude     float64
# Dropoff Centroid Longitude    float64
# ...

# %%
data_df.columns
# Out:
# Index(['Trip ID', 'Taxi ID', 'Trip Start Timestamp', 'Trip End Timestamp',
#        'Trip Seconds', 'Trip Miles', 'Pickup Census Tract',
#        'Dropoff Census Tract', 'Pickup Community Area',
#        'Dropoff Community Area', 'Fare', 'Tips', 'Tolls', 'Extras',
#        'Trip Total', 'Payment Type', 'Company', 'Pickup Centroid Latitude',
#        'Pickup Centroid Longitude', 'Pickup Centroid Location',
#        'Dropoff Centroid Latitude', 'Dropoff Centroid Longitude',
#        'Dropoff Centroid  Location', 'Community Areas'],
#       dtype='object')

# %%
len(data_df.columns)
# Out:
# 24

# %%
dict(data_df.dtypes)
# Out:
# {'Trip ID': dtype('O'),
#  'Taxi ID': dtype('O'),
#  'Trip Start Timestamp': dtype('O'),
#  'Trip End Timestamp': dtype('O'),
#  'Trip Seconds': dtype('float64'),
#  'Trip Miles': dtype('float64'),
#  'Pickup Census Tract': dtype('float64'),
#  'Dropoff Census Tract': dtype('float64'),
#  'Pickup Community Area': dtype('float64'),
#  'Dropoff Community Area': dtype('float64'),
#  'Fare': dtype('float64'),
#  'Tips': dtype('float64'),
#  'Tolls': dtype('float64'),
#  'Extras': dtype('float64'),
#  'Trip Total': dtype('float64'),
#  'Payment Type': dtype('O'),
#  'Company': dtype('O'),
#  'Pickup Centroid Latitude': dtype('float64'),
#  'Pickup Centroid Longitude': dtype('float64'),
#  'Pickup Centroid Location': dtype('O'),
#  'Dropoff Centroid Latitude': dtype('float64'),
#  'Dropoff Centroid Longitude': dtype('float64'),
#  'Dropoff Centroid  Location': dtype('O'),
#  'Community Areas': dtype('float64')}
