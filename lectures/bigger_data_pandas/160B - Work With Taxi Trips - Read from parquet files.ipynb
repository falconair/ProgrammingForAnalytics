# %%
import pandas as pd
import pyarrow.parquet as pq

# %% [markdown]
# ### Go through a large csv and convert to parquet

# %%
dataset = pq.ParquetDataset("../../datasets/taxi-trips/taxi_trips_parquet")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f885b784b805> in <module>
# ----> 1 dataset = pq.ParquetDataset("../datasets/taxi-trips/taxi_trips_parquet")
#
# ~/anaconda3/lib/python3.7/site-packages/pyarrow/parquet.py in __init__(self, path_or_paths, filesystem, schema, metadata, split_row_groups, validate_schema, filters, metadata_nthreads)
#     910
#     911         if validate_schema:
# --> 912             self.validate_schemas()
#     913
#     914         if filters is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pyarrow/parquet.py in validate_schemas(self)
#     944                                  '{1!s}\n\nvs\n\n{2!s}'
#     945                                  .format(piece, file_schema,
# --> 946                                          dataset_schema))
#     947
#     948     def read(self, columns=None, use_threads=True, use_pandas_metadata=False):
#
# ValueError: Schema in ../datasets/taxi-trips/taxi_trips_parquet/taxi_trips_109.parquet was different.
# Trip ID: string
# Taxi ID: string
# Trip Start Timestamp: timestamp[ms]
# Trip End Timestamp: timestamp[ms]
# Trip Seconds: double
# Trip Miles: double
# Pickup Census Tract: double
# Dropoff Census Tract: double
# Pickup Community Area: double
# Dropoff Community Area: double
# Fare: double
# Tips: double
# Tolls: double
# Extras: double
# Trip Total: double
# Payment Type: string
# Company: null
# Pickup Centroid Latitude: double
# Pickup Centroid Longitude: double
# Dropoff Centroid Latitude: double
# Dropoff Centroid Longitude: double
# Community Areas: double
# __index_level_0__: int64
# metadata
# --------
# OrderedDict([(b'pandas',
#               b'{"index_columns": ["__index_level_0__"], "column_indexes": ['
#               b'{"name": null, "field_name": null, "pandas_type": "unicode",'
#               b' "numpy_type": "object", "metadata": {"encoding": "UTF-8"}}]'
#               b', "columns": [{"name": "Trip ID", "field_name": "Trip ID", "'
#               b'pandas_type": "unicode", "numpy_type": "object", "metadata":'
#               b' null}, {"name": "Taxi ID", "field_name": "Taxi ID", "pandas'
#               b'_type": "categorical", "numpy_type": "int16", "metadata": {"'
#               b'num_categories": 1011, "ordered": false}}, {"name": "Trip St'
#               b'art Timestamp", "field_name": "Trip Start Timestamp", "panda'
#               b's_type": "datetime", "numpy_type": "datetime64[ns]", "metada'
#               b'ta": null}, {"name": "Trip End Timestamp", "field_name": "Tr'
#               b'ip End Timestamp", "pandas_type": "datetime", "numpy_type": '
#               b'"datetime64[ns]", "metadata": null}, {"name": "Trip Seconds"'
#               b', "field_name": "Trip Seconds", "pandas_type": "float64", "n'
#               b'umpy_type": "float64", "metadata": null}, {"name": "Trip Mil'
#               b'es", "field_name": "Trip Miles", "pandas_type": "float64", "'
#               b'numpy_type": "float64", "metadata": null}, {"name": "Pickup '
#               b'Census Tract", "field_name": "Pickup Census Tract", "pandas_'
#               b'type": "float64", "numpy_type": "float64", "metadata": null}'
#               b', {"name": "Dropoff Census Tract", "field_name": "Dropoff Ce'
#               b'nsus Tract", "pandas_type": "float64", "numpy_type": "float6'
#               b'4", "metadata": null}, {"name": "Pickup Community Area", "fi'
#               b'eld_name": "Pickup Community Area", "pandas_type": "float64"'
#               b', "numpy_type": "float64", "metadata": null}, {"name": "Drop'
#               b'off Community Area", "field_name": "Dropoff Community Area",'
#               b' "pandas_type": "float64", "numpy_type": "float64", "metadat'
#               b'a": null}, {"name": "Fare", "field_name": "Fare", "pandas_ty'
#               b'pe": "float64", "numpy_type": "float64", "metadata": null}, '
#               b'{"name": "Tips", "field_name": "Tips", "pandas_type": "float'
#               b'64", "numpy_type": "float64", "metadata": null}, {"name": "T'
#               b'olls", "field_name": "Tolls", "pandas_type": "float64", "num'
#               b'py_type": "float64", "metadata": null}, {"name": "Extras", "'
#               b'field_name": "Extras", "pandas_type": "float64", "numpy_type'
#               b'": "float64", "metadata": null}, {"name": "Trip Total", "fie'
#               b'ld_name": "Trip Total", "pandas_type": "float64", "numpy_typ'
#               b'e": "float64", "metadata": null}, {"name": "Payment Type", "'
#               b'field_name": "Payment Type", "pandas_type": "categorical", "'
#               b'numpy_type": "int8", "metadata": {"num_categories": 4, "orde'
#               b'red": false}}, {"name": "Company", "field_name": "Company", '
#               b'"pandas_type": "categorical", "numpy_type": "int8", "metadat'
#               b'a": {"num_categories": 0, "ordered": false}}, {"name": "Pick'
#               b'up Centroid Latitude", "field_name": "Pickup Centroid Latitu'
#               b'de", "pandas_type": "float64", "numpy_type": "float64", "met'
#               b'adata": null}, {"name": "Pickup Centroid Longitude", "field_'
#               b'name": "Pickup Centroid Longitude", "pandas_type": "float64"'
#               b', "numpy_type": "float64", "metadata": null}, {"name": "Drop'
#               b'off Centroid Latitude", "field_name": "Dropoff Centroid Lati'
#               b'tude", "pandas_type": "float64", "numpy_type": "float64", "m'
#               b'etadata": null}, {"name": "Dropoff Centroid Longitude", "fie'
#               b'ld_name": "Dropoff Centroid Longitude", "pandas_type": "floa'
#               b't64", "numpy_type": "float64", "metadata": null}, {"name": "'
#               b'Community Areas", "field_name": "Community Areas", "pandas_t'
#               b'ype": "float64", "numpy_type": "float64", "metadata": null},'
#               b' {"name": null, "field_name": "__index_level_0__", "pandas_t'
#               b'ype": "int64", "numpy_type": "int64", "metadata": null}], "p'
#               b'andas_version": "0.24.2"}')])
#
# vs
#
# Trip ID: string
# Taxi ID: string
# Trip Start Timestamp: timestamp[ms]
# Trip End Timestamp: timestamp[ms]
# Trip Seconds: double
# Trip Miles: double
# Pickup Census Tract: double
# Dropoff Census Tract: double
# Pickup Community Area: double
# Dropoff Community Area: double
# Fare: double
# Tips: double
# Tolls: double
# Extras: double
# Trip Total: double
# Payment Type: string
# Company: string
# Pickup Centroid Latitude: double
# Pickup Centroid Longitude: double
# Dropoff Centroid Latitude: double
# Dropoff Centroid Longitude: double
# Community Areas: double
# __index_level_0__: int64
# metadata
# --------
# OrderedDict([(b'pandas',
#               b'{"index_columns": ["__index_level_0__"], "column_indexes": ['
#               b'{"name": null, "field_name": null, "pandas_type": "unicode",'
#               b' "numpy_type": "object", "metadata": {"encoding": "UTF-8"}}]'
#               b', "columns": [{"name": "Trip ID", "field_name": "Trip ID", "'
#               b'pandas_type": "unicode", "numpy_type": "object", "metadata":'
#               b' null}, {"name": "Taxi ID", "field_name": "Taxi ID", "pandas'
#               b'_type": "categorical", "numpy_type": "int16", "metadata": {"'
#               b'num_categories": 4540, "ordered": false}}, {"name": "Trip St'
#               b'art Timestamp", "field_name": "Trip Start Timestamp", "panda'
#               b's_type": "datetime", "numpy_type": "datetime64[ns]", "metada'
#               b'ta": null}, {"name": "Trip End Timestamp", "field_name": "Tr'
#               b'ip End Timestamp", "pandas_type": "datetime", "numpy_type": '
#               b'"datetime64[ns]", "metadata": null}, {"name": "Trip Seconds"'
#               b', "field_name": "Trip Seconds", "pandas_type": "float64", "n'
#               b'umpy_type": "float64", "metadata": null}, {"name": "Trip Mil'
#               b'es", "field_name": "Trip Miles", "pandas_type": "float64", "'
#               b'numpy_type": "float64", "metadata": null}, {"name": "Pickup '
#               b'Census Tract", "field_name": "Pickup Census Tract", "pandas_'
#               b'type": "float64", "numpy_type": "float64", "metadata": null}'
#               b', {"name": "Dropoff Census Tract", "field_name": "Dropoff Ce'
#               b'nsus Tract", "pandas_type": "float64", "numpy_type": "float6'
#               b'4", "metadata": null}, {"name": "Pickup Community Area", "fi'
#               b'eld_name": "Pickup Community Area", "pandas_type": "float64"'
#               b', "numpy_type": "float64", "metadata": null}, {"name": "Drop'
#               b'off Community Area", "field_name": "Dropoff Community Area",'
#               b' "pandas_type": "float64", "numpy_type": "float64", "metadat'
#               b'a": null}, {"name": "Fare", "field_name": "Fare", "pandas_ty'
#               b'pe": "float64", "numpy_type": "float64", "metadata": null}, '
#               b'{"name": "Tips", "field_name": "Tips", "pandas_type": "float'
#               b'64", "numpy_type": "float64", "metadata": null}, {"name": "T'
#               b'olls", "field_name": "Tolls", "pandas_type": "float64", "num'
#               b'py_type": "float64", "metadata": null}, {"name": "Extras", "'
#               b'field_name": "Extras", "pandas_type": "float64", "numpy_type'
#               b'": "float64", "metadata": null}, {"name": "Trip Total", "fie'
#               b'ld_name": "Trip Total", "pandas_type": "float64", "numpy_typ'
#               b'e": "float64", "metadata": null}, {"name": "Payment Type", "'
#               b'field_name": "Payment Type", "pandas_type": "categorical", "'
#               b'numpy_type": "int8", "metadata": {"num_categories": 9, "orde'
#               b'red": false}}, {"name": "Company", "field_name": "Company", '
#               b'"pandas_type": "categorical", "numpy_type": "int8", "metadat'
#               b'a": {"num_categories": 49, "ordered": false}}, {"name": "Pic'
#               b'kup Centroid Latitude", "field_name": "Pickup Centroid Latit'
#               b'ude", "pandas_type": "float64", "numpy_type": "float64", "me'
#               b'tadata": null}, {"name": "Pickup Centroid Longitude", "field'
#               b'_name": "Pickup Centroid Longitude", "pandas_type": "float64'
#               b'", "numpy_type": "float64", "metadata": null}, {"name": "Dro'
#               b'poff Centroid Latitude", "field_name": "Dropoff Centroid Lat'
#               b'itude", "pandas_type": "float64", "numpy_type": "float64", "'
#               b'metadata": null}, {"name": "Dropoff Centroid Longitude", "fi'
#               b'eld_name": "Dropoff Centroid Longitude", "pandas_type": "flo'
#               b'at64", "numpy_type": "float64", "metadata": null}, {"name": '
#               b'"Community Areas", "field_name": "Community Areas", "pandas_'
#               b'type": "float64", "numpy_type": "float64", "metadata": null}'
#               b', {"name": null, "field_name": "__index_level_0__", "pandas_'
#               b'type": "int64", "numpy_type": "int64", "metadata": null}], "'
#               b'pandas_version": "0.24.2"}')])
